# %%
# Rastrigin
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D 
 
X = np.linspace(-5.12, 5.12, 100)     
Y = np.linspace(-5.12, 5.12, 100)     
X, Y = np.meshgrid(X, Y) 

Z = (X**2 - 10 * np.cos(2 * np.pi * X)) + \
  (Y**2 - 10 * np.cos(2 * np.pi * Y)) + 20
 
fig = plt.figure() 
ax = fig.gca(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
# plt.savefig('rastrigin_graph.png')
plt.show()

# %%
# Six-Hump-Camel
X = np.linspace(-3, 3, 100)     
Y = np.linspace(-2, 2, 100)     
X, Y = np.meshgrid(X, Y) 

Z = (4 - 2.1 * (X ** 2) + (X ** 4) / 3) * X ** 2 + X * Y + (-4 + 4 * (Y ** 2)) * Y ** 2

fig = plt.figure() 
ax = fig.gca(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
# plt.savefig('sixhumpcamel.png')
plt.show()

# %%
# Six-Hump-Camel
X = np.linspace(-3, 3, 100)     
Y = np.linspace(-2, 2, 100)     
X, Y = np.meshgrid(X, Y) 


def ackley(self, inputs: []):
    first_term = -20 * math.exp(-0.2 * math.sqrt((1 / len(inputs)) * sum([param ** 2 for param in inputs])))
    second_term = math.exp((1 / len(inputs)) * sum([math.cos(2 * math.pi * param) for param in inputs]))

    return first_term - second_term + 20 + math.e

fig = plt.figure() 
ax = fig.gca(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
# plt.savefig('sixhumpcamel.png')
plt.show()
# Out:
#   File "<ipython-input-31-238023311ef5>", line 13
#     Z = [ackley([test,testt]) for test in X,Y]
#                                            ^
# SyntaxError: invalid syntax

# %%
X
# Out:
# array([[-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        ...,
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ]])
